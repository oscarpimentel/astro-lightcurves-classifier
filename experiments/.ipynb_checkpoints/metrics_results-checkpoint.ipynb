# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../fuzzy-torch') # or just install the module
sys.path.append('../../fuzzy-tools') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.utils import get_model_names

rootdir = '../save'
set_name = 'test'
method = 'spm-mcmc-estw'
cfilename = f'survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
kf = '.'

model_names = get_model_names(rootdir, cfilename, kf, set_name)
model_names
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=202~pb=.~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1',
#  'mdl=SerialTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=8~time_noise_window=6*24**-1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~b=202~pb=.~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1']

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from lcclassifier.results.performance import plot_metric

metric_names = [
    #'precision',
    #'recall',
    #'f1score',
    'aucroc',
    #'aucpr',
    ]

bypass_prob = 0.0
ds_prob = 0.1
new_model_names = []
for model_name in model_names:
    if not 'pb=.' in model_name:
        continue
    if f'bypass_synth=0~bypass_prob={bypass_prob}~ds_prob={ds_prob}' in model_name:
        new_model_names += [model_name]
plot_metric(rootdir, cfilename, kf, set_name, new_model_names, metric_names,
    std_prop=1/2,
    #target_class='SNIa', # SLSN SNIbc SNIIbn SNIa
    #baseline_rootdir=None,
    #dict_name='thdays_class_metrics_all_bands',
    )

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.cm import plot_cm

new_model_names = []
for model_name in model_names:
    if not 'b=202' in model_name:
        #continue
        pass
    if 'RNN' in model_name:
        continue
        pass
    if 'Attn' in model_name:
        #continue
        pass
    new_model_names += [model_name]
plot_cm(rootdir, cfilename, kf, set_name, new_model_names,
    #export_animation=True,
    #dict_name='thdays_class_metrics_all_bands',
    )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ids=['0@id=1000c0', '0@id=1000c1', '0@id=1001c0', '0@id=1001c1', '0@id=1002c0', '0@id=1002c1', '0@id=1003c0', '0@id=1003c1', '1@id=1000c0', '1@id=1000c1', '1@id=1001c0', '1@id=1001c1', '1@id=1002c0', '1@id=1002c1', '1@id=1003c0', '1@id=1003c1', '2@id=1000c0', '2@id=1000c1', '2@id=1001c0', '2@id=1001c1', '2@id=1002c0', '2@id=1002c1', '2@id=1003c0', '2@id=1003c1', '3@id=1000c0', '3@id=1000c1', '3@id=1001c0', '3@id=1001c1', '3@id=1002c0', '3@id=1002c1', '3@id=1003c0', '3@id=1003c1', '4@id=1000c0', '4@id=1000c1', '4@id=1001c0', '4@id=1001c1', '4@id=1002c0', '4@id=1002c1', '4@id=1003c0', '4@id=1000c0'](n=40#); model=mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=202~pb=.~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1
# 100%|██████████| 1/1 [00:00, 10.03it/s, thday=100.000 [days]]
# file_id=0@id=1000c0; b-recall=0.7398968784791735; b-f1score=0.5640239818885453; b-aucroc=0.9030394028827065;
# file_id=0@id=1000c1; b-recall=0.7503842172273705; b-f1score=0.5814826786066828; b-aucroc=0.9078010744899452;
# file_id=0@id=1001c0; b-recall=0.7070313744181953; b-f1score=0.5440182821496533; b-aucroc=0.9063778332751969;
# file_id=0@id=1001c1; b-recall=0.6998885172753484; b-f1score=0.5361442401196705; b-aucroc=0.902031449478021;
# file_id=0@id=1002c0; b-recall=0.7248885172752233; b-f1score=0.547812777524547; b-aucroc=0.9022074517375624;
# file_id=0@id=1002c1; b-recall=0.7259515846426343; b-f1score=0.550814185253362; b-aucroc=0.9115913449460825;
# file_id=0@id=1003c0; b-recall=0.7214305621868814; b-f1score=0.5540840611769822; b-aucroc=0.8982911730342419;
# file_id=0@id=1003c1; b-recall=0.7258381111596423; b-f1score=0.5641776733952563; b-aucroc=0.9009004557260482;
# file_id=1@id=1000c0; b-recall=0.7464285714239427; b-f1score=0.5906902379014285; b-aucroc=0.897346754415471;
# file_id=1@id=1000c1; b-recall=0.7464285714239427; b-f1score=0.5906902379014285; b-aucroc=0.8966983404574673;
# file_id=1@id=1001c0; b-recall=0.7369047619001869; b-f1score=0.573275583902396; b-aucroc=0.8916332197739243;
# file_id=1@id=1001c1; b-recall=0.7322619047573392; b-f1score=0.5740100024923591; b-aucroc=0.8930592169355467;
# file_id=1@id=1002c0; b-recall=0.698690476186548; b-f1score=0.5558243485271439; b-aucroc=0.9049933850189915;
# file_id=1@id=1002c1; b-recall=0.700357142853214; b-f1score=0.5602796697815368; b-aucroc=0.9049820631826694;
# file_id=1@id=1003c0; b-recall=0.7115476190431305; b-f1score=0.5686636276885143; b-aucroc=0.896780274424746;
# file_id=1@id=1003c1; b-recall=0.7132142857097967; b-f1score=0.5721302273099128; b-aucroc=0.8979234174309679;
# file_id=2@id=1000c0; b-recall=0.7496739130383336; b-f1score=0.6003549009786875; b-aucroc=0.899481290615395;
# file_id=2@id=1000c1; b-recall=0.7521739130383327; b-f1score=0.6055782457304176; b-aucroc=0.9008576784185399;
# file_id=2@id=1001c0; b-recall=0.7799637681106665; b-f1score=0.6096309832195027; b-aucroc=0.9029107968586269;
# file_id=2@id=1001c1; b-recall=0.7391304347780274; b-f1score=0.5970216071399158; b-aucroc=0.9051038836977492;
# file_id=2@id=1002c0; b-recall=0.7371739130389016; b-f1score=0.5974082934151728; b-aucroc=0.9119726337763192;
# file_id=2@id=1002c1; b-recall=0.7438768115896119; b-f1score=0.6010361508164579; b-aucroc=0.9067089072319193;
# file_id=2@id=1003c0; b-recall=0.7374637681113613; b-f1score=0.6011724668542769; b-aucroc=0.898121440087687;
# file_id=2@id=1003c1; b-recall=0.7382971014446943; b-f1score=0.6026628796929157; b-aucroc=0.8996866577653017;
# file_id=3@id=1000c0; b-recall=0.8565476190420551; b-f1score=0.663521017160971; b-aucroc=0.9361131554434484;
# file_id=3@id=1000c1; b-recall=0.8576190476134795; b-f1score=0.6568395228153511; b-aucroc=0.9366650060388639;
# file_id=3@id=1001c0; b-recall=0.8654761904705691; b-f1score=0.6721538613643983; b-aucroc=0.9502457608244325;
# file_id=3@id=1001c1; b-recall=0.8488095238039665; b-f1score=0.6482216303878492; b-aucroc=0.9495106502612458;
# file_id=3@id=1002c0; b-recall=0.8008333333279747; b-f1score=0.6181940206760941; b-aucroc=0.9409615547356112;
# file_id=3@id=1002c1; b-recall=0.7864285714232798; b-f1score=0.6039982391486096; b-aucroc=0.9419115519410031;
# file_id=3@id=1003c0; b-recall=0.8179761904708183; b-f1score=0.6506103102810892; b-aucroc=0.946960184548334;
# file_id=3@id=1003c1; b-recall=0.8073809523756382; b-f1score=0.643688901621089; b-aucroc=0.9467029473150165;
# file_id=4@id=1000c0; b-recall=0.7622750437921331; b-f1score=0.6366864534635488; b-aucroc=0.9116037057206234;
# file_id=4@id=1000c1; b-recall=0.7482162764725127; b-f1score=0.6098663872849325; b-aucroc=0.9135613486021262;
# file_id=4@id=1001c0; b-recall=0.7276238254453986; b-f1score=0.6016017248839812; b-aucroc=0.9107087302013772;
# file_id=4@id=1001c1; b-recall=0.7792821309072958; b-f1score=0.6071871914372037; b-aucroc=0.9047474679492298;
# file_id=4@id=1002c0; b-recall=0.7614389233907957; b-f1score=0.6151894653768215; b-aucroc=0.9131788439686128;
# file_id=4@id=1002c1; b-recall=0.7603758560233846; b-f1score=0.6190975094241964; b-aucroc=0.9136045775826387;
# file_id=4@id=1003c0; b-recall=0.690705128201253; b-f1score=0.5852471478503976; b-aucroc=0.9019686749165108;
# file_id=4@id=1000c0; b-recall=0.7622750437921331; b-f1score=0.6366864534635488; b-aucroc=0.9116037057206234;
# p_SNIa_tp = [87.62541806020067, 88.96321070234113, 86.62207357859532, 86.62207357859532, 86.62207357859532, 85.61872909698997, 85.95317725752508, 86.2876254180602, 86.66666666666667, 86.66666666666667, 85.0, 86.0, 85.66666666666667, 86.33333333333333, 87.0, 87.66666666666667, 84.0, 85.0, 84.66666666666667, 85.0, 85.66666666666667, 84.0, 84.33333333333334, 84.66666666666667, 83.33333333333334, 82.33333333333334, 83.33333333333334, 81.66666666666667, 80.33333333333333, 81.0, 84.33333333333334, 83.66666666666667, 87.29096989966555, 85.95317725752508, 86.2876254180602, 85.28428093645485, 86.95652173913044, 87.95986622073578, 84.61538461538461, 87.29096989966555]
# p_SNIbc_tp = [75.0, 75.0, 60.0, 60.0, 70.0, 70.0, 65.0, 65.0, 70.0, 70.0, 65.0, 65.0, 70.0, 70.0, 60.0, 60.0, 55.00000000000001, 55.00000000000001, 65.0, 65.0, 65.0, 65.0, 65.0, 65.0, 85.0, 85.0, 90.0, 85.0, 70.0, 65.0, 70.0, 65.0, 70.0, 70.0, 60.0, 65.0, 70.0, 70.0, 65.0, 70.0]
# p_SNII*_tp = [50.0, 52.85714285714286, 52.85714285714286, 50.0, 50.0, 51.42857142857142, 54.285714285714285, 55.714285714285715, 58.57142857142858, 58.57142857142858, 61.42857142857143, 58.57142857142858, 57.14285714285714, 57.14285714285714, 54.285714285714285, 54.285714285714285, 60.86956521739131, 60.86956521739131, 62.31884057971014, 62.31884057971014, 60.86956521739131, 65.21739130434783, 62.31884057971014, 62.31884057971014, 74.28571428571429, 75.71428571428571, 72.85714285714285, 72.85714285714285, 70.0, 68.57142857142857, 72.85714285714285, 74.28571428571429, 64.28571428571429, 60.0, 61.42857142857143, 61.42857142857143, 64.28571428571429, 62.857142857142854, 60.0, 64.28571428571429]
# p_SLSN_tp = [83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 66.66666666666666, 66.66666666666666, 83.33333333333334, 83.33333333333334, 100.0, 100.0, 100.0, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 83.33333333333334, 83.33333333333334, 83.33333333333334, 100.0, 83.33333333333334, 83.33333333333334, 66.66666666666666, 83.33333333333334]
# ids=['0@id=1000c0', '0@id=1000c1', '0@id=1001c0', '0@id=1001c1', '0@id=1002c0', '0@id=1002c1', '0@id=1003c0', '0@id=1003c1', '1@id=1000c0', '1@id=1000c1', '1@id=1001c0', '1@id=1001c1', '1@id=1002c0', '1@id=1002c1', '1@id=1003c0', '1@id=1003c1', '2@id=1000c0', '2@id=1000c1', '2@id=1001c0', '2@id=1001c1', '2@id=1002c0', '2@id=1002c1', '2@id=1003c0', '2@id=1003c1', '3@id=1000c0', '3@id=1000c1', '3@id=1001c0', '3@id=1001c1', '3@id=1002c0', '3@id=1002c1', '3@id=1003c0', '3@id=1003c1', '4@id=1000c0', '4@id=1000c1', '4@id=1001c0', '4@id=1001c1', '4@id=1002c0', '4@id=1002c1', '4@id=1001c0', '4@id=1002c0'](n=40#); model=mdl=SerialTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=8~time_noise_window=6*24**-1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~b=202~pb=.~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1
# 100%|██████████| 1/1 [00:00, 13.01it/s, thday=100.000 [days]]
# file_id=0@id=1000c0; b-recall=0.7286868928127204; b-f1score=0.5529792949022176; b-aucroc=0.9130295476290783;
# file_id=0@id=1000c1; b-recall=0.7528507724112578; b-f1score=0.5605495801009693; b-aucroc=0.9109645211155969;
# file_id=0@id=1001c0; b-recall=0.7491658703568422; b-f1score=0.5702343188416793; b-aucroc=0.897599198613037;
# file_id=0@id=1001c1; b-recall=0.7447583213840814; b-f1score=0.5645946670047491; b-aucroc=0.8986194531410245;
# file_id=0@id=1002c0; b-recall=0.7430860805814063; b-f1score=0.5628184680704691; b-aucroc=0.9056578703402332;
# file_id=0@id=1002c1; b-recall=0.7464305621867564; b-f1score=0.5696775644270186; b-aucroc=0.8991853745203233;
# file_id=0@id=1003c0; b-recall=0.7351071030372218; b-f1score=0.5553216986620567; b-aucroc=0.9054445371522408;
# file_id=0@id=1003c1; b-recall=0.7344979296019577; b-f1score=0.5462665753193598; b-aucroc=0.9028668869402272;
# file_id=1@id=1000c0; b-recall=0.7378571428525209; b-f1score=0.5681642795255641; b-aucroc=0.9029096129705241;
# file_id=1@id=1000c1; b-recall=0.7386904761858542; b-f1score=0.5690664255368677; b-aucroc=0.9008439095755638;
# file_id=1@id=1001c0; b-recall=0.7874999999946732; b-f1score=0.5948532698332476; b-aucroc=0.93286658982565;
# file_id=1@id=1001c1; b-recall=0.7858333333280072; b-f1score=0.5914373897270491; b-aucroc=0.9326181430943783;
# file_id=1@id=1002c0; b-recall=0.7780952380899767; b-f1score=0.5948864194428339; b-aucroc=0.9219335231470459;
# file_id=1@id=1002c1; b-recall=0.7839285714232498; b-f1score=0.5883773919847257; b-aucroc=0.9208779116171468;
# file_id=1@id=1003c0; b-recall=0.7258333333288243; b-f1score=0.5800077970676852; b-aucroc=0.9025140938948903;
# file_id=1@id=1003c1; b-recall=0.7274999999954905; b-f1score=0.5856174002095361; b-aucroc=0.9010846676105679;
# file_id=2@id=1000c0; b-recall=0.7347101449230067; b-f1score=0.5969212549507701; b-aucroc=0.8949916704834363;
# file_id=2@id=1000c1; b-recall=0.7338768115896737; b-f1score=0.5966168502031337; b-aucroc=0.8935071723920498;
# file_id=2@id=1001c0; b-recall=0.7347101449230067; b-f1score=0.5896220501832768; b-aucroc=0.8898933219757142;
# file_id=2@id=1001c1; b-recall=0.7374999999954654; b-f1score=0.5857282679473821; b-aucroc=0.8879116566678789;
# file_id=2@id=1002c0; b-recall=0.7224637681114245; b-f1score=0.5828960157161589; b-aucroc=0.891500178437517;
# file_id=2@id=1002c1; b-recall=0.7257971014447568; b-f1score=0.5849606064769113; b-aucroc=0.8916035490286097;
# file_id=2@id=1003c0; b-recall=0.7296739130389042; b-f1score=0.5728991596197435; b-aucroc=0.8911062256454997;
# file_id=2@id=1003c1; b-recall=0.728840579705571; b-f1score=0.5732144596148894; b-aucroc=0.8944034561750329;
# file_id=3@id=1000c0; b-recall=0.8471428571373003; b-f1score=0.6445527422698959; b-aucroc=0.9446272206352075;
# file_id=3@id=1000c1; b-recall=0.8473809523753916; b-f1score=0.6527061931654761; b-aucroc=0.9442896848232825;
# file_id=3@id=1001c0; b-recall=0.8359523809469367; b-f1score=0.6772444216715616; b-aucroc=0.9490564985901349;
# file_id=3@id=1001c1; b-recall=0.8359523809469367; b-f1score=0.6780941165591651; b-aucroc=0.9456078557437102;
# file_id=3@id=1002c0; b-recall=0.8147619047564871; b-f1score=0.6399186018033814; b-aucroc=0.9454244894901814;
# file_id=3@id=1002c1; b-recall=0.8183333333279106; b-f1score=0.6382098433215153; b-aucroc=0.9458752419096716;
# file_id=3@id=1003c0; b-recall=0.8408333333277864; b-f1score=0.6348069122890678; b-aucroc=0.946026294653167;
# file_id=3@id=1003c1; b-recall=0.8266666666611828; b-f1score=0.6270215053321918; b-aucroc=0.945629472493724;
# file_id=4@id=1000c0; b-recall=0.7316491479488798; b-f1score=0.591658307737625; b-aucroc=0.9045076153792929;
# file_id=4@id=1000c1; b-recall=0.7333213887515546; b-f1score=0.5943320583719063; b-aucroc=0.8997272400688057;
# file_id=4@id=1001c0; b-recall=0.7109432234386843; b-f1score=0.570087066353922; b-aucroc=0.885098643850375;
# file_id=4@id=1001c1; b-recall=0.7372332377720437; b-f1score=0.5931190948921449; b-aucroc=0.8864812916192262;
# file_id=4@id=1002c0; b-recall=0.7413003662957391; b-f1score=0.5994517073949024; b-aucroc=0.9029755147631698;
# file_id=4@id=1002c1; b-recall=0.7440356744658252; b-f1score=0.6017678275867551; b-aucroc=0.8990056339203064;
# file_id=4@id=1001c0; b-recall=0.7109432234386843; b-f1score=0.570087066353922; b-aucroc=0.885098643850375;
# file_id=4@id=1002c0; b-recall=0.7413003662957391; b-f1score=0.5994517073949024; b-aucroc=0.9029755147631698;
# s_SNIa_tp = [85.28428093645485, 84.94983277591973, 85.61872909698997, 85.28428093645485, 84.61538461538461, 85.95317725752508, 84.2809364548495, 82.6086956521739, 84.66666666666667, 85.0, 85.0, 84.33333333333334, 87.66666666666667, 85.0, 87.0, 87.66666666666667, 85.33333333333334, 85.0, 85.33333333333334, 85.0, 83.33333333333334, 84.66666666666667, 82.66666666666667, 82.33333333333334, 81.0, 79.66666666666666, 83.66666666666667, 83.66666666666667, 82.33333333333334, 82.33333333333334, 81.33333333333333, 80.66666666666666, 83.61204013377926, 84.2809364548495, 84.61538461538461, 82.2742474916388, 84.61538461538461, 84.2809364548495, 84.61538461538461, 84.61538461538461]
# s_SNIbc_tp = [70.0, 80.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 70.0, 70.0, 70.0, 70.0, 65.0, 70.0, 60.0, 60.0, 60.0, 60.0, 60.0, 60.0, 60.0, 60.0, 65.0, 65.0, 85.0, 85.0, 75.0, 75.0, 75.0, 75.0, 85.0, 80.0, 70.0, 70.0, 65.0, 75.0, 70.0, 70.0, 65.0, 70.0]
# s_SNII*_tp = [52.85714285714286, 52.85714285714286, 55.714285714285715, 54.285714285714285, 54.285714285714285, 54.285714285714285, 51.42857142857142, 52.85714285714286, 57.14285714285714, 57.14285714285714, 60.0, 60.0, 58.57142857142858, 58.57142857142858, 60.0, 60.0, 65.21739130434783, 65.21739130434783, 65.21739130434783, 66.66666666666666, 62.31884057971014, 62.31884057971014, 60.86956521739131, 60.86956521739131, 72.85714285714285, 74.28571428571429, 75.71428571428571, 75.71428571428571, 68.57142857142857, 70.0, 70.0, 70.0, 55.714285714285715, 55.714285714285715, 51.42857142857142, 54.285714285714285, 58.57142857142858, 60.0, 51.42857142857142, 58.57142857142858]
# s_SLSN_tp = [83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 100.0, 100.0, 100.0, 100.0, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334]

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.tables import get_ps_performance_df
from fuzzytools.latex.latex_tables import LatexTable

metric_names = [
    'precision',
    'recall',
    'f1score',
    'aucroc',
    'aucpr',
    ]

bypass_prob = 0.0
ds_prob = 0.1
new_model_names = []
for model_name in model_names:
    if not 'pb=.' in model_name:
        continue
    if f'bypass_synth=0~bypass_prob={bypass_prob}~ds_prob={ds_prob}' in model_name:
        new_model_names += [model_name]
info_df = get_ps_performance_df(rootdir, cfilename, kf, set_name, new_model_names, metric_names,
    #uses_avg=True,
    #dict_name='thdays_class_metrics_all_bands',
    #target_class='SNIa', # SNIa
    #'override_model_name':False, # False True
    #baseline_rootdir=None,
    )
for k in range(0, len(info_df)):
    info_df.indexs[k] = info_df.indexs[k].replace('=', '***')
    info_df.indexs[k] = info_df.indexs[k].replace('Model***', 'Model=')
display(info_df())

latex_table = LatexTable(info_df(),
    centered=True,
    repr_replace_dict={
        '***':'=',
        '-999.000±.000':'--',
        },
    )
print(latex_table)

# %%
# %load_ext autoreload
# %autoreload 2
from fuzzytools.datascience import statistical_tests as statistical_tests
from lcclassifier import _C

def get_dict(info_df, metric_name, str_to_ignore, ds_prob):
    df = info_df.get_df()
    df = df[[c for c in df.columns if _C.METRICS_D[metric_name]['mn'] in c]]
    values_dict = df.to_dict()
    values_dict = values_dict[list(values_dict.keys())[0]]
    new_values_dict = {}
    for k in values_dict.keys():
        if 'BRF' in k:
            new_values_dict[k] = values_dict[k]
        else:
            if str_to_ignore in k:
                continue
            if f'bypass_synth***1' in k:
                continue
            if f'ds_prob***{ds_prob}' in k:
                new_values_dict[k] = values_dict[k]
            
    return new_values_dict

metric_names = [
    'precision',
    'recall',
    'f1score',
    'aucroc',
    'aucpr',
    ]
ds_prob = 0.0
for str_to_ignore in ['Models=P', 'Models=S']:
#ds_prob = 0.1
#for str_to_ignore in ['RNN']:
    for metric_name in metric_names:
        print(f'str_to_ignore={str_to_ignore}; metric_name={metric_name}; ds_prob={ds_prob}')
        values_dict = get_dict(info_df, metric_name, str_to_ignore, ds_prob)
        test = statistical_tests.permutationtest # ttest welchtest permutationtest
        df = statistical_tests.gridtest_greater(values_dict, test,
            test_kwargs={'num_rounds':1e5}, # 1e4 1e5
            th_pvalue_txt=0,
            n_decimals=4,
            check_samples=False,
            )
        display(df)
