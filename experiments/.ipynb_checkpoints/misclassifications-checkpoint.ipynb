# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../fuzzy-tools') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
from lcclassifier.results.utils import get_model_names

lcset_name = 'test'
rootdir = '../save'
method = 'spm-mcmc-estw'
cfilename = f'survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
kf = '4'

model_names = get_model_names(rootdir, cfilename, kf, lcset_name)
model_names
# Out:
# ['mdl=SerialRNN~input_dims=1~dummy_seft=1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~cell=GRU~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1',
#  'mdl=ParallelRNN~input_dims=1~dummy_seft=1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~cell=LSTM~b=203~pb=.~hr=0~bypass_synth=1~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=203~pb=.~hr=0~bypass_synth=1~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=SerialRNN~input_dims=1~dummy_seft=1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~cell=LSTM~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.5',
#  'mdl=ParallelRNN~input_dims=1~dummy_seft=1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~cell=LSTM~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.5',
#  'mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=203~pb=r~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1',
#  'mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=203~pb=g~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1',
#  'mdl=SerialRNN~input_dims=1~dummy_seft=1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~cell=GRU~b=203~pb=.~hr=0~bypass_synth=1~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=ParallelRNN~input_dims=1~dummy_seft=1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~cell=GRU~b=203~pb=.~hr=0~bypass_synth=1~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=SerialTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=8~time_noise_window=6*24**-1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~b=206~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1',
#  'mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=206~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1',
#  'mdl=SerialTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=8~time_noise_window=6*24**-1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~b=206~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.5',
#  'mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=206~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.5',
#  'mdl=SerialTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=8~time_noise_window=6*24**-1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~b=199~pb=.~hr=0~bypass_synth=0~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=199~pb=.~hr=0~bypass_synth=0~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.5',
#  'mdl=ParallelRNN~input_dims=1~dummy_seft=1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~cell=GRU~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.5',
#  'mdl=ParallelRNN~input_dims=1~dummy_seft=1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~cell=GRU~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1',
#  'mdl=SerialRNN~input_dims=1~dummy_seft=1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~cell=GRU~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=SerialTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=8~time_noise_window=6*24**-1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=SerialRNN~input_dims=1~dummy_seft=1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~cell=GRU~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.5',
#  'mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=ParallelRNN~input_dims=1~dummy_seft=1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~cell=GRU~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=SerialTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=8~time_noise_window=6*24**-1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1',
#  'mdl=SerialTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=8~time_noise_window=6*24**-1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.5',
#  'mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1',
#  'mdl=SerialRNN~input_dims=1~dummy_seft=1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~cell=LSTM~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=ParallelRNN~input_dims=1~dummy_seft=1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~cell=LSTM~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=SerialRNN~input_dims=1~dummy_seft=1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~cell=LSTM~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1',
#  'mdl=ParallelRNN~input_dims=1~dummy_seft=1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~cell=LSTM~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1',
#  'mdl=SerialRNN~input_dims=1~dummy_seft=1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~cell=LSTM~b=203~pb=.~hr=0~bypass_synth=1~bypass_prob=1.0~ds_prob=0.0',
#  'mdl=SerialTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=8~time_noise_window=6*24**-1~enc_emb=128-128~dec_emb=g1-g128.r1-r128~b=203~pb=.~hr=0~bypass_synth=1~bypass_prob=1.0~ds_prob=0.0']

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import fuzzytools.files as ftfiles
from fuzzytools.datascience import misclassifications
import matplotlib.pyplot as plt

model_name = 'mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1'
rootdir = '../save'
train_mode = 'fine-tuning'
load_roodir = f'{rootdir}/{model_name}/{train_mode}/performance/{cfilename}'
files, files_ids, kfs = ftfiles.gather_files_by_kfold(load_roodir, kf, lcset_name,
    fext='d',
    imbalanced_kf_mode='ignore', # error oversampling
    )
print(f'{files_ids}({len(files_ids)}#); {model_name}')

file_idx = 0
file = files[file_idx]
thdays = file()['thdays']
thday = thdays[-1]
thdays_predictions = file()['thdays_predictions'][thday]
y_pred_p = thdays_predictions['y_pred_p']
y_true = thdays_predictions['y_true']
class_names = file()['class_names']
obj_ids = file()['lcobj_names']

fig, axs, miss_objs_df = misclassifications.plot_misclassification_map(y_pred_p, y_true, class_names,
    obj_ids=obj_ids,
    #pred_prob_th=.8, # None .5
    fontsize=12,
    figsize=(20,18),
    legend_loc='upper right',
    #verbose=1,
    also_show_correct_objs_txt=True,
    )
display(miss_objs_df)
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['id=1000c0', 'id=1000c1', 'id=1001c0', 'id=1001c1', 'id=1002c0', 'id=1002c1', 'id=1003c0', 'id=1003c1', 'id=1004c0', 'id=1004c1', 'id=1005c0', 'id=1005c1'](12#); mdl=ParallelTimeModAttn~input_dims=1~dummy_seft=1~m=24~kernel_size=1~heads=4~time_noise_window=6*24**-1~enc_emb=g64-g64.r64-r64~dec_emb=g1-g128.r1-r128~b=203~pb=.~hr=0~bypass_synth=0~bypass_prob=0.0~ds_prob=0.1
#                   c obj_y_pred_c  obj_y_pred_p
# ZTF19aamgwse  SNII*        SNIbc      0.507880
# ZTF19abzqwpr  SNII*         SNIa      0.702210
# ZTF19aakphow  SNII*         SLSN      0.481855
# ZTF19aasmddt  SNII*        SNIbc      0.872919
# ZTF19abkfqqp  SNII*        SNIbc      0.901348
# ...             ...          ...           ...
# ZTF18adalgmc   SNIa        SNIbc      0.568392
# ZTF20aaymbjk   SNIa        SNIbc      0.691518
# ZTF20aaelulu  SNIbc        SNII*      0.492970
# ZTF18abukavn  SNIbc         SNIa      0.514311
# ZTF18abbovuc  SNIbc         SNIa      0.775259
#
# [71 rows x 3 columns]

# %%
txt = ''
for miss_obj_id in miss_objs_df.index:
    txt += f"'{miss_obj_id}', "
print(f'deep_miss_obj_ids = [{txt}]')
# Out:
# deep_miss_obj_ids = ['ZTF19aamgwse', 'ZTF19abzqwpr', 'ZTF19aakphow', 'ZTF19aasmddt', 'ZTF19abkfqqp', 'ZTF19acgzzea', 'ZTF20aatzhhl', 'ZTF19aadtqcd', 'ZTF19aaqasrq', 'ZTF20aaurfwa', 'ZTF19aavqics', 'ZTF19abqrxhy', 'ZTF19acvmcdd', 'ZTF19aasekcx', 'ZTF20aapjiwl', 'ZTF19aawethd', 'ZTF18absbgqd', 'ZTF20aahirfz', 'ZTF18acbwawc', 'ZTF20aazdxlx', 'ZTF18acrncou', 'ZTF18adacoaj', 'ZTF19abqsvue', 'ZTF18aceathd', 'ZTF19aakrnqh', 'ZTF18accwjiu', 'ZTF19aatvmbo', 'ZTF19aaputrv', 'ZTF18abobkii', 'ZTF20abegopd', 'ZTF18acaeous', 'ZTF18abddrhd', 'ZTF18adbckhw', 'ZTF18acbzojv', 'ZTF20aapcmur', 'ZTF18acbvgry', 'ZTF20abbbumr', 'ZTF20abdajyr', 'ZTF20aasxerr', 'ZTF18abvglon', 'ZTF19aatvvvu', 'ZTF20aaurmtf', 'ZTF20aadxvfj', 'ZTF20aabqdbo', 'ZTF19abqgxpt', 'ZTF19aaafgbt', 'ZTF18achmxsx', 'ZTF18adathpb', 'ZTF19abnmnrz', 'ZTF19acklbjr', 'ZTF20aahaxjl', 'ZTF19aaykugs', 'ZTF19abrirdm', 'ZTF18acehilk', 'ZTF18aaodrgt', 'ZTF19aawlnlq', 'ZTF20aasokxu', 'ZTF19aboqpry', 'ZTF19aajwhse', 'ZTF20aaurjzv', 'ZTF19aayabqe', 'ZTF19aaflnoi', 'ZTF18abywcnl', 'ZTF19abpbmli', 'ZTF19acfthre', 'ZTF19aatlmbo', 'ZTF18adalgmc', 'ZTF20aaymbjk', 'ZTF20aaelulu', 'ZTF18abukavn', 'ZTF18abbovuc', ]
